# %%
import pandas as pd

file_path = r"C:\Users\Msi\OneDrive\Desktop\Nuova cartella\E-PROT-59-query-results.tsv"

# Salta le righe iniziali commentate
df = pd.read_csv(file_path, sep="\t", comment='#')

# Controlla le prime righe
df.head()

# Controlla le colonne
print(df.columns)
# Out:
# Index(['Gene ID', 'Gene Name',
#        ''clear cell renal cell carcinoma' vs 'normal' .foldChange',
#        ''clear cell renal cell carcinoma' vs 'normal'.pValue',
#        ''papillary renal cell carcinoma' vs 'clear cell renal cell carcinoma' .foldChange',
#        ''papillary renal cell carcinoma' vs 'clear cell renal cell carcinoma'.pValue'],
#       dtype='object')
