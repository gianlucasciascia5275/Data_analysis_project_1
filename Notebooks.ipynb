# %%
import pandas as pd

# Percorso del file TSV
file_path = r"C:\Users\Msi\OneDrive\Desktop\Nuova cartella\Data\E-PROT-59-query-results.tsv"

# Filtra i geni con p-value < 0.05 per la prima condizione
sig_genes = df[df["'clear cell renal cell carcinoma' vs 'normal'.pValue"] < 0.05]

# Mostra i primi geni significativi
sig_genes.head()
# Out:
#             Gene ID Gene Name  \
# 5   ENSG00000004455       AK2
# 7   ENSG00000005022   SLC25A5
# 11  ENSG00000008294     SPAG9
# 13  ENSG00000011304     PTBP1
# 16  ENSG00000013364       MVP
#
#     'clear cell renal cell carcinoma' vs 'normal' .foldChange  \
# 5                                                 0.8
# 7                                                 2.1
# 11                                                1.6
# 13                                               -0.7
# 16                                               -1.5
#
#     'clear cell renal cell carcinoma' vs 'normal'.pValue  \
# 5                                        2.780000e-07
# 7                                        1.520000e-08
# 11                                       2.870000e-05
# 13                                       2.240000e-05
# 16                                       1.900000e-06
#
#     'papillary renal cell carcinoma' vs 'clear cell renal cell carcinoma' .foldChange  \
# ...
