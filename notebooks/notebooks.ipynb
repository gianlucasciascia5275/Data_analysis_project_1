# %%
import pandas as pd
import os

# Percorso relativo al file TSV (compatibile con GitHub)
file_path = os.path.join("..", "data", "E-PROT-59-query-results.tsv")

# Verifica che il file esista
assert os.path.exists(file_path), "File TSV non trovato nella cartella data/"

# Caricamento del dataset di espressione differenziale
df = pd.read_csv(file_path, sep="\t", comment="#")

# Filtraggio dei geni con p-value < 0.05
sig_genes = df[df["'clear cell renal cell carcinoma' vs 'normal'.pValue"] < 0.05]


sig_genes.head()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 19
#      14 sig_genes = df[df["'clear cell renal cell carcinoma' vs 'normal'.pValue"] < 0.05]
#      17 sig_genes.head()
# ---> 19 sig_genes.to_csv(
#      20     os.path.join("..", "results", "significant_genes_ccRCC_vs_normal.csv"),
#      21     index=False
#      22 )
#
# File c:\Users\Msi\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
